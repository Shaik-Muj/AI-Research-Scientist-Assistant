# %% [markdown]
# # Basic RAG Query DemoThis notebook demonstrates the **Basic RAG** system for simple Q&A using research papers.**Basic RAG** = Single-step retrieval + answer generationPerfect for:- Factual questions- Quick lookups- Simple queries

# %% [markdown]
# ## Setup

# %%
import syssys.path.append('..')from rag_query import BasicRAGprint("[OK] Imports successful")

# %% [markdown]
# ## Initialize RAG System

# %%
# Initialize Basic RAGrag = BasicRAG()print("[OK] Basic RAG initialized")

# %% [markdown]
# ## Example 1: Simple Factual Question

# %%
question = "What is GRU?"print(f"Question: {question}\n")result = rag.query(question, n_results=3)print("Answer:")print("-" * 80)print(result['answer'])print("-" * 80)print(f"\nSources ({result['num_sources']} papers):")for i, source in enumerate(result['sources'], 1):print(f"{i}. {source['title']}")

# %% [markdown]
# ## Example 2: Performance Question

# %%
question = "How does GRU perform on small datasets?"print(f"Question: {question}\n")result = rag.query(question, n_results=5)print("Answer:")print("-" * 80)print(result['answer'])print("-" * 80)print(f"\nSources ({result['num_sources']} papers):")for i, source in enumerate(result['sources'], 1):print(f"{i}. {source['title']}")print(f"  URL: {source['url']}")

# %% [markdown]
# ## Example 3: Methodology Question

# %%
question = "What datasets are commonly used for evaluating GRU models?"print(f"Question: {question}\n")result = rag.query(question, n_results=5)print("Answer:")print("-" * 80)print(result['answer'])print("-" * 80)

# %% [markdown]
# ## Interactive Query

# %%
# Ask your own question!your_question = input("Enter your question: ")if your_question:result = rag.query(your_question, n_results=5)print("\nAnswer:")print("-" * 80)print(result['answer'])print("-" * 80)print(f"\nBased on {result['num_sources']} papers")

# %% [markdown]
# ## Summary**Basic RAG** is perfect for:- - Quick factual questions- - Simple lookups- - Fast responses**Limitations**:- - Can't handle complex multi-step reasoning- - Single retrieval step only- - No comparison or synthesis across multiple retrievalsFor complex queries, use **Agentic RAG** (see agentic_rag_demo.ipynb)!
